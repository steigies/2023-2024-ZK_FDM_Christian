# %% [markdown]
# # Alles Neu macht der Januar

# %%
import urllib.request
import pandas as pd
checkout_file = "checkout.csv"
checkouts_df = pd.read_csv(checkout_file)
checkouts_df
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0       Digital    OverDrive        EBOOK          2018              1
# 1       Digital       Hoopla   TELEVISION          2018              1
# 2      Physical      Horizon    SOUNDDISC          2018              1
# 3       Digital    OverDrive        EBOOK          2018              1
# 4       Digital    OverDrive        EBOOK          2018              1
# ...         ...          ...          ...           ...            ...
# 9995    Digital    OverDrive        EBOOK          2018              1
# 9996    Digital    OverDrive        EBOOK          2018              1
# 9997    Digital      Freegal         SONG          2018              1
# 9998   Physical      Horizon         BOOK          2018              1
# 9999   Physical      Horizon    SOUNDDISC          2018              1
#
#       checkouts                                              title  isbn  \
# ...

# %%
data = checkouts_df.checkouts

# %%
hist = data.hist(bins=20)
#print(hist)

# %%
print("min checkout: %d\t max checkout: %d" % (data.min(), data.max()))
#print(data[data > 100].sort_values())
#print(data[data < 10].count())
# Out:
# min checkout: 1	 max checkout: 540

# %%
checkouts_df[checkouts_df.checkouts >= 100]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 2170   Physical      Horizon    VIDEODISC          2018              1
# 3056    Digital    OverDrive    AUDIOBOOK          2018              1
# 6084   Physical      Horizon         BOOK          2018              1
# 6638   Physical      Horizon         BOOK          2018              1
# 7785   Physical      Horizon    VIDEODISC          2018              1
# 9255    Digital        Zinio     MAGAZINE          2018              1
# 9700   Physical      Horizon         BOOK          2018              1
#
#       checkouts                                              title  isbn  \
# 2170        105  Ghostbusters / Columbia Pictures ; in associat...   NaN
# 3056        106  The Underground Railroad (Oprah's Book Club): ...   NaN
# 6084        114           George & Lizzie : a novel / Nancy Pearl.   NaN
# 6638        540  In the midst of winter : a novel / Isabel Alle...   NaN
# ...

# %%
for i in range(1, checkouts_df.checkouts.max()+1):
    num = len(checkouts_df[checkouts_df.checkouts==i])
    if num >0:
        print("checkouts: %4i \t how often: %4i" % (i, num))
# Out:
# checkouts:    1 	 how often: 5057
# checkouts:    2 	 how often: 1847
# checkouts:    3 	 how often:  950
# checkouts:    4 	 how often:  561
# checkouts:    5 	 how often:  373
# checkouts:    6 	 how often:  233
# checkouts:    7 	 how often:  175
# checkouts:    8 	 how often:  139
# checkouts:    9 	 how often:  102
# checkouts:   10 	 how often:   97
# checkouts:   11 	 how often:   51
# checkouts:   12 	 how often:   53
# checkouts:   13 	 how often:   54
# checkouts:   14 	 how often:   18
# checkouts:   15 	 how often:   30
# checkouts:   16 	 how often:   33
# checkouts:   17 	 how often:   20
# checkouts:   18 	 how often:   17
# checkouts:   19 	 how often:   16
# checkouts:   20 	 how often:   16
# checkouts:   21 	 how often:   10
# checkouts:   22 	 how often:   13
# checkouts:   23 	 how often:    8
# checkouts:   24 	 how often:   10
# checkouts:   25 	 how often:    8
# checkouts:   26 	 how often:    2
# checkouts:   27 	 how often:    7
# ...

# %%
checkouts_df["checkouts"].value_counts().sort_index()  # values_counts ist nicht sortiert nach checkouts
# Out:
# 1      5057
# 2      1847
# 3       950
# 4       561
# 5       373
#        ...
# 114       1
# 176       1
# 354       1
# 495       1
# 540       1
# Name: checkouts, Length: 79, dtype: int64

# %%
checkouts_df["materialtype"].value_counts()
# Out:
# BOOK                    4268
# EBOOK                   2084
# AUDIOBOOK                857
# SOUNDDISC                839
# VIDEODISC                806
# SONG                     707
# MUSIC                    139
# MOVIE                     94
# TELEVISION                85
# COMIC                     62
# SOUNDDISC, VIDEODISC      10
# MAGAZINE                  10
# SOUNDREC                   8
# REGPRINT                   7
# VIDEO                      5
# CR                         4
# ER, SOUNDDISC              3
# ER                         3
# MAP                        3
# ATLAS                      2
# LARGEPRINT                 1
# VIDEOCASS, VIDEODISC       1
# SOUNDCASS                  1
# ER, VIDEODISC              1
# Name: materialtype, dtype: int64

# %%
checkouts_df[checkouts_df["materialtype"] == "VIDEODISC"].title
# Out:
# 220     Quarry. The complete first season / Cinemax Or...
# 239     Ch'unhyangdyŏn = Chunhyang / Mirae Asset ; Tae...
# 243     Havana time machine : a musical journey throug...
# 247     Chicago P.D. Season four / Wolf Films ; Univer...
# 262     The librarians. Season three / Electric Entert...
#                               ...
# 9907    Poetic justice / Columbia Pictures ; a New Dea...
# 9940    Monsieur Lazhar / Music Box Films ; Micro_Scop...
# 9961    The bounce back / Ankle Socks and Baseball Pan...
# 9974    Home improvement. The complete seventh season ...
# 9994    Symbols of resistance : a tribute to the marty...
# Name: title, Length: 806, dtype: object

# %%
checkouts_df[checkouts_df["materialtype"] == "MAGAZINE"]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 199     Digital        Zinio     MAGAZINE          2018              1
# 434     Digital        Zinio     MAGAZINE          2018              1
# 620     Digital        Zinio     MAGAZINE          2018              1
# 816     Digital        Zinio     MAGAZINE          2018              1
# 4133    Digital        Zinio     MAGAZINE          2018              1
# 6576    Digital        Zinio     MAGAZINE          2018              1
# 7611    Digital        Zinio     MAGAZINE          2018              1
# 9255    Digital        Zinio     MAGAZINE          2018              1
# 9732    Digital        Zinio     MAGAZINE          2018              1
# 9969    Digital        Zinio     MAGAZINE          2018              1
#
#       checkouts                         title  isbn creator subjects  \
# 199          49                 Family Circle   NaN     NaN      NaN
# ...
